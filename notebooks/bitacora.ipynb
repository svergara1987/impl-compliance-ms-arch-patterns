# %% [markdown]
# # Bitacora
# ---

# %% [markdown]
# ## Randoop

# %%
/Library/Java/JavaVirtualMachines/jdk1.8.0_181.jdk/Contents/Home/bin/java -Xmx3000m -classpath "/Users/svergara/Box/personales/fing/tesis de maestria/randoop/randoop-4.2.3/randoop-all-4.2.3.jar:/Users/svergara/eclipse/default-workspace/JMLTest/bin/" randoop.main.Main gentests --testclass=Timer --junit-output-dir="/Users/svergara/eclipse/default-workspace/RandoopTest/src/randoop"

# %% [markdown]
# ## Jupyter

# %%
pip3 install jupyter

# %% [markdown]
# Then add ```/Library/Frameworks/Python.framework/Versions/3.7/bin``` to path

# %%
pip3 install jupyterlab

# %%
pip3 install jupyterlab-git

# %% [markdown]
# Jupyter Kernel prob2: https://gitlab.cs.uni-duesseldorf.de/general/stups/prob2-jupyter-kernel

# %% [markdown]
# Jupyter Kernel zsh:

# %%
python3 -m pip install notebook zsh_jupyter_kernel

# %% [markdown]
# Jupyter Kernel groovy/java

# %%
pip3 install py4j

# %%
pip3 install beakerx

# %%
beakerx install

# %% [markdown]
# ## PROB

# %% [markdown]
# ProB home page: https://www3.hhu.de/stups/prob/index.php/Main_Page

# %% [markdown]
# Google Group Prob users: https://groups.google.com/forum/#!forum/prob-users

# %% [markdown]
# ### PROB Java API

# %% [markdown]
# User manual Java API: https://www3.hhu.de/stups/handbook/prob2/prob_handbook.html

# %% [markdown]
# ### PROB CLI

# %%
probcli -help

# %%
probcli --version

# %% [markdown]
# Worked

# %%
cd "/Users/svergara/Box/personales/fing/tesis de maestria"

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -cbc_tests 5 circuit_breaker=OPEN eventb_compliance/eventb2xml/test/test_open.xml -p CLPFD true -p TIME_OUT 60000

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -cbc_tests 5 circuit_breaker=HALF_OPEN eventb_compliance/eventb2xml/test/test_half_open.xml -p CLPFD true -p TIME_OUT 60000

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -cbc_tests 10 test_request_to_go=0 eventb_compliance/eventb2xml/test/test_closed.xml -p CLPFD true -p TIME_OUT 60000

# %%
probcli -animate 100 -his eventb_compliance/eventb2xml/test -his_option show_init -his_option show_states eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -i

# %% [markdown]
# Didn't work

# %%
cd "/Users/svergara/Box/personales/fing/tesis de maestria"

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -mcm_tests 10 100 "circuit_breaker=OPEN ∨ test_request_to_go=0 ∨ circuit_breaker=HALF_OPEN" eventb_compliance/eventb2xml/test/tests_mcm.xml

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -mc 100 -spdot eventb_compliance/eventb2xml/test/state_space.dot

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -mc 1000 -c

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -mc 1000 --coverage_summary

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -cbc_sequence "request(TRUE);request(FALSE);request(FALSE)"

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -cbc_sequence "request(TRUE);request(FALSE);request(FALSE)" -save_state

# %%
probcli eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb -enabling_analysis

# %% [markdown]
# ### probcli_test_generator.py

# %%
cd "/Users/svergara/Box/personales/fing/tesis de maestria"
pwd
# Out:
# /Users/svergara/Box/personales/fing/tesis de maestria

# %%
gradle run --args="--machine '/Users/svergara/Box/personales/fing/tesis de maestria/eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb' --strategy '/Users/svergara/Box/personales/fing/tesis de maestria/eventb_compliance/eventb2xml/test/out.xml/sequence/edges_coverage.yaml'" -p "eventb_compliance/eventb2xml/java"
# Out:
# > Connecting to Daemon> IDLE<-------------> 0% INITIALIZING s]> Evaluating settings<-------------> 0% CONFIGURING s]> root project<-------------> 0% CONFIGURING s]<=============> 100% CONFIGURING s]> IDLE<=============> 100% CONFIGURING s]<=============> 100% CONFIGURING s]<=============> 100% CONFIGURING s]<=============> 100% CONFIGURING s]<-------------> 0% EXECUTING s]> :compileJava<-------------> 0% EXECUTING s]> :compileJava > Resolve dependencies of :compileClasspath<-------------> 0% EXECUTING [1s]> :compileJava > Resolve files of :compileClasspath<===----------> 25% EXECUTING [1s]> :processResources<=========----> 75% EXECUTING [1s]> :run > Resolve dependencies of :runtimeClasspath> :run<=========----> 75% EXECUTING [2s]<=========----> 75% EXECUTING [3s]
# > Task :run
# WARNING: An illegal reflective access operation has occurred
# ...

# %%
rm -rf "eventb_compliance/eventb2xml/test/delete_out.xml"
rm -rf "eventb_compliance/eventb2xml/test/out.xml"
rm "eventb_compliance/eventb2xml/test/out.xml"
python3 eventb_compliance/eventb2xml/py/probcli_test_generator.py --strategy "eventb_compliance/eventb2xml/test/strategy.yaml" --machine "eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb" --keep --verbose --output "eventb_compliance/eventb2xml/test/out.xml"
# Out:
# rm: eventb_compliance/eventb2xml/test/out.xml: No such file or directory
# 2020-07-18 18:45:48,658 - program arguments=Namespace(keep=True, machine='eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb', output='eventb_compliance/eventb2xml/test/out.xml', strategy='eventb_compliance/eventb2xml/test/strategy.yaml', verbose=True)
# 2020-07-18 18:45:48,658 - getting absolute paths from relatives
# 2020-07-18 18:45:48,661 - machine file 'eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb' -> '/Users/svergara/Box/personales/fing/tesis de maestria/probcli/eventb_compliance/eventb2xml/eventb_machines/m0_circuit_breaker_mch.eventb'
# 2020-07-18 18:45:48,663 - test strategy file 'eventb_compliance/eventb2xml/test/strategy.yaml' -> '/Users/svergara/Box/personales/fing/tesis de maestria/probcli/eventb_compliance/eventb2xml/test/strategy.yaml'
# ...

# %% [markdown]
# ## SPRING

# %% [markdown]
# Download and install Spring Tools: https://spring.io/tools

# %% [markdown]
# This code was tested with
# ```
# Spring Tool Suite 4
#
# Version: 4.7.0.RELEASE
# Build Id: 202006181331
# ```

# %% [markdown]
# Followed this tutorial: https://spring.io/guides/gs/circuit-breaker/ (https://github.com/spring-guides/gs-circuit-breaker)

# %% [markdown]
# Spring Initializr: https://start.spring.io/

# %% [markdown]
# ![spring initializr.png](http://localhost:8888/files/notebooks/resources/spring%20initializr.png)

# %% [markdown]
# Hystrix configs: https://github.com/Netflix/Hystrix/wiki/Configuration

# %% [markdown]
# Short Spring tutorial: https://www.tutorialspoint.com/spring_boot

# %% [markdown]
# ## JUnit

# %% [markdown]
# Short JUnit tutorial: https://www.tutorialspoint.com/junit/index.htm

# %% [markdown]
# ## Mocha

# %% [markdown]
# ## xml2junit

# %% [markdown]
# Template: `mvn archetype:generate -DgroupId=uy.edu.fing.svergara -DartifactId=${projectName} -DinteractiveMode=false`
#
# Instanciado: `mvn archetype:generate -DgroupId=uy.edu.fing.svergara -DartifactId=junit-circuit-breaker -DinteractiveMode=false`

# %% [markdown]
# ## Apache Velocity

# %% [markdown]
# Developer guide: https://velocity.apache.org/engine/2.2/developer-guide.html
